# %% [markdown]
# ## Sección 0 — Setup e instalación
# - Instalación de dependencias.
# - Imports.
# - Definición de seed.
# - Definición de DEVICE. (si quieren usar gpu, ojala si para hacerlo rápido)
# - Imports desde src si ya modularizaron. (Aun nó)
# ---

# %% [markdown]
# ## Librerias y imports

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.models import resnet18, ResNet18_Weights

import medmnist
from medmnist import INFO

from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix
)

from tqdm.auto import tqdm

# %% [markdown]
# ## Definición de SEED y device

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

DATA_FLAG = "pathmnist"
SIZE = 28
BATCH_SIZE = 256
NUM_WORKERS = 2

info = INFO[DATA_FLAG]
DataClass = getattr(medmnist, info["python_class"])

n_classes = len(info["label"])
class_names = [info["label"][str(i)] for i in range(n_classes)]

print("Dispositivo:", DEVICE)
print("Dataset:", DATA_FLAG)
print("Resolución:", SIZE, "x", SIZE)
print("Número de clases:", n_classes)
print("Clases:", class_names)
# Out:
# Dispositivo: cuda
# Dataset: pathmnist
# Resolución: 28 x 28
# Número de clases: 9
# Clases: ['adipose', 'background', 'debris', 'lymphocytes', 'mucus', 'smooth muscle', 'normal colon mucosa', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium']

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 1 — Carga del dataset PathMNIST
# - Cargar train, val y test.
# - Mostrar tamaños oficiales.
# - Explicar que MedMNIST ya trae particiones oficiales. (ya que vienen directamente en train, val, test, lo que se comentó en el readme)
# - No usar random_split.
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 2 — EDA global del dataset
# - Cantidad total de imágenes.
# - Cantidad por split.
# - Número de clases.
# - Diccionario label → clase. (esto se va a modularizar)
# - Distribución global de clases.
# - Distribución por split, opcional pero me parece lo mejor dado el contexto.
# - Grid de muestras visuales con nombres de clase (dentro del dataset.ipynb tienen como se puede visualizar los tensores) .
# ---

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 3 — Preprocesamiento y DataLoaders
# - Transformaciones para ResNet18.
# - Conversión a tensor.
# - Normalización.
# - Resize si usan backbone preentrenado.
# - DataLoaders train, val y test.
# - Verificación de un batch: shape de imágenes y labels.
# (Todos estos terminos los vamos a conversar cuando no reunamos porque es parte de una investigacion que tenemos que hacer)
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 4 — Modelo principal: ResNet18 preentrenada
# - Cargar ResNet18 con pesos preentrenados.
# - Reemplazar capa final para 9 clases.
# - Definir si se congela backbone o se hace fine-tuning parcial.
# - Mostrar número de parámetros entrenables.
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 5 — Configuración de entrenamiento
# - Loss: CrossEntropyLoss.
# - Optimizador: AdamW o Adam. (pueden ver los cuadernos del profe cual les tinca más)
# - Scheduler si lo usan, pero no es obligatorio.
# - Número de epochs.
# - Funciones auxiliares de entrenamiento y validación. (esto se modulizará)
# ---

# %%
EPOCHS = 20
EARLY_STOPPING_PATIENCE = 5
LEARNING_RATE = 1e-4
early_stopping_counter = 0

criterion = nn.CrossEntropyLoss()

optimizer = optim.AdamW(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=LEARNING_RATE,
    weight_decay=1e-4
)


# Con esto, bajamos el learnig rate suavemente hasta casi 0 
# en la ultima epoca, evitando saltar una buena solución mediante el avance de las epocas
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer, 
    T_max=EPOCHS
)

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 6 — Entrenamiento
# - Entrenar usando train.
# - Validar usando val.
# - Guardar historial de loss y accuracy. (directo a `/metrics`)
# - Guardar mejor modelo según val_acc o val_f1.
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 7 — Evaluación final en test
# - Cargar mejor modelo.
# - Evaluar una sola vez en test.
# - Calcular Accuracy.
# - Calcular F1-macro.
# - Generar matriz de confusión.
# - Generar reporte por clase si alcanza el tiempo (yo creo que si).
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 8 — Visualizaciones finales
# - Curvas de loss.
# - Curvas de accuracy (En realidad aca creo que es mejor f1-score al ser temas médicos).
# - Matriz de confusión.
# - Tabla resumen de métricas.
# - Opcional: ejemplos de aciertos y errores.
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## Sección 9 — Conclusiones breves
# - Resultado principal.
# - Limitaciones de trabajar en 28x28.
# - Observación sobre resolución baja.
# - Trabajo futuro: 128x128 y Transformers para la segunda entrega.
# ---
# > Esta parte es más relevante para el .pptx, igual se tiene que hacer

# %% [markdown]
# ---
